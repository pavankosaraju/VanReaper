# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl
import datetime
import math
# %matplotlib inline

# %%
df = pd.read_csv("../data/property_tax_report_2018.csv")

# %%
new = df["PROPERTY_POSTAL_CODE"].str.split(" ", n = 1, expand = True) 
df["AREA"]= new[0] 
df["SUB_AREA"]= new[1]

# %%
area_v6b = df[(df['AREA'] == 'V6B')]

# %%
area_v6b.to_csv('../data/area_v6b.csv')

# %%
area_v6b.dropna(inplace=True,subset=['YEAR_BUILT'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
area_v6b.isna().sum()
# Out:
# PID                              39
# LEGAL_TYPE                        0
# FOLIO                             0
# LAND_COORDINATE                   0
# ZONE_NAME                         0
# ZONE_CATEGORY                     2
# LOT                              77
# BLOCK                         16330
# PLAN                              4
# DISTRICT_LOT                   2270
# FROM_CIVIC_NUMBER              1042
# TO_CIVIC_NUMBER                   0
# STREET_NAME                       0
# PROPERTY_POSTAL_CODE              0
# NARRATIVE_LEGAL_LINE1            19
# NARRATIVE_LEGAL_LINE2            73
# NARRATIVE_LEGAL_LINE3          3160
# NARRATIVE_LEGAL_LINE4          9042
# NARRATIVE_LEGAL_LINE5         10305
# CURRENT_LAND_VALUE                0
# CURRENT_IMPROVEMENT_VALUE         0
# TAX_ASSESSMENT_YEAR               0
# PREVIOUS_LAND_VALUE               0
# PREVIOUS_IMPROVEMENT_VALUE        0
# YEAR_BUILT                        0
# BIG_IMPROVEMENT_YEAR              0
# ...

# %%
area_v6b = area_v6b.drop(['TAX_LEVY'], axis=1)
# Out:
#                 PID LEGAL_TYPE         FOLIO  LAND_COORDINATE   ZONE_NAME  \
# 23      018-375-201     STRATA  1.576120e+11         15761223  CD-1 (266)
# 24      027-572-463     STRATA  1.576020e+11         15760203  CD-1 (431)
# 25      018-117-945     STRATA  1.566030e+11         15660296          DD
# 26      026-911-574     STRATA  1.566050e+11         15660467          DD
# 33      027-172-554     STRATA  1.616000e+11         16159994  CD-1 (415)
# 507     024-472-689     STRATA  6.021390e+11         60213896          DD
# 867     015-501-922       LAND  5.921570e+11         59215747          DD
# 943     027-388-751     STRATA  1.346130e+11         13461255          DD
# 1102    018-843-671     STRATA  1.526070e+11         15260650        HA-3
# 1103    027-260-216     STRATA  1.616000e+11         16159956  CD-1 (415)
# 1233    023-394-463     STRATA  1.526090e+11         15260894        HA-3
# 1556    025-768-093     STRATA  1.386060e+11         13860604          DD
# ...
